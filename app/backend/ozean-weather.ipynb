# %%
import fastapi
import uvicorn
from utils.Database import Database
from utils.Copernicus import AdvancedCopernicus
from utils.OpenMeteoWeather import OpenMeteoWeather
from utils.PlanetPositions import PlanetPositions
import pandas as pd
import numpy as np
import datetime
from tqdm import tqdm
import json

# %%
print(datetime.datetime.now().isoformat())
# Out:
# 2025-02-23T12:22:13.052445

# %%
# ------------ Initialize the global Variables ------------

# Define Absolute maximum and minimum values for date and location
ABSOLUTE_END_DATE:str = datetime.datetime.now().isoformat().split("T")[0]

ABSOLUTE_MINIMUM_LONGITUDE:float = 9.041532516479492
ABSOLUTE_MAXIMUM_LONGITUDE:float = 30.208656311035156
ABSOLUTE_MINIMUM_LATIDUDE:float = 53.00829315185547
ABSOLUTE_MAXIMUM_LATIDUDE:float = 65.89141845703125




START_DATE:str = "2025-01-01"
END_DATE:str = "2025-02-1"



MINIMUM_LONGITUDE:float = 9.59
MAXIMUM_LONGITUDE:float = 12.037
MINIMUM_LATIDUDE:float = 55.486
MAXIMUM_LATIDUDE:float = 55.616


# For Testing
MINIMUM_LONGITUDE=10.038345850696412
MAXIMUM_LONGITUDE=10.365962458698567
MINIMUM_LATIDUDE=54.27381478077755
MAXIMUM_LATIDUDE=54.52976525577923

OUTPUT_FILENAME:str = "output.nc"




DB_URL = 'localhost'
DB_NAME = 'deep-learning'
DB_COLLECTION = 'ozean-weather'

# %%
# ------------ Initialize the classes ------------


AdvancedCopernicus = AdvancedCopernicus()

# %%
def process_dataframe(df:pd.DataFrame) -> pd.DataFrame:
    for column in df.select_dtypes(include=["float"]).columns:
        df[column] = df[column].astype(np.float32)  # Konvertiere alle Float-Typen zu float32
    df["latitude"] = df["latitude"].astype(np.float32).round(6)
    df["longitude"] = df["longitude"].astype(np.float32).round(6)
    df['time'] = pd.to_datetime(df['time']).dt.tz_localize(None)

    return df

# %%
# ------------ Get data from AdvancedCopernicus ------------
copernicus_data = AdvancedCopernicus.get_subset(
                dataset_id="cmems_mod_bal_phy_anfc_PT1H-i",
                dataset_version="202411",
                variables=["bottomT", "mlotst", "siconc", "sithick", "sla", "so", "sob", "thetao", "uo", "vo", "wo"], 
                minimum_longitude=MINIMUM_LONGITUDE,
                maximum_longitude=MAXIMUM_LONGITUDE,
                minimum_latitude=MINIMUM_LATIDUDE,
                maximum_latitude=MAXIMUM_LATIDUDE,
                start_datetime=START_DATE,
                end_datetime=END_DATE,
                minimum_depth=0.5016462206840515,
                maximum_depth=0.5016462206840515,
                coordinates_selection_method="strict-inside",
                disable_progress_bar=False,
                output_filename=OUTPUT_FILENAME
                )
# Out:
# INFO - 2025-02-23T11:22:14Z - Selected dataset version: "202411"
# INFO - 2025-02-23T11:22:14Z - Selected dataset part: "default"
# INFO - 2025-02-23T11:22:19Z - Starting download. Please wait...
#   0%|          | 0/44 [00:00<?, ?it/s]
# INFO - 2025-02-23T11:22:22Z - Successfully downloaded to output.nc

# %%
# plot xarray dataset in map
print(copernicus_data)
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:    (depth: 1, latitude: 16, longitude: 12, time: 745)
# Coordinates:
#   * depth      (depth) float32 4B 0.5016
#   * latitude   (latitude) float32 64B 54.27 54.29 54.31 ... 54.49 54.51 54.52
#   * longitude  (longitude) float32 48B 10.04 10.07 10.1 ... 10.29 10.32 10.35
#   * time       (time) datetime64[ns] 6kB 2025-01-01 ... 2025-02-01
# Data variables:
#     bottomT    (time, latitude, longitude) float32 572kB ...
#     mlotst     (time, latitude, longitude) float32 572kB ...
#     siconc     (time, latitude, longitude) float32 572kB ...
#     sithick    (time, latitude, longitude) float32 572kB ...
#     sla        (time, latitude, longitude) float32 572kB ...
#     so         (time, depth, latitude, longitude) float32 572kB ...
#     sob        (time, latitude, longitude) float32 572kB ...
#     thetao     (time, depth, latitude, longitude) float32 572kB ...
#     uo         (time, depth, latitude, longitude) float32 572kB ...
#     vo         (time, depth, latitude, longitude) float32 572kB ...
#     wo         (time, depth, latitude, longitude) float32 572kB ...
# Attributes:
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     comment:                   Data on cropped native product grid. Horizonta...
#     references:                https://marine.copernicus.eu/
#     title:                     CMEMS NEMO hourly model fields
#     Conventions:               CF-1.0
#     source:                    CMEMS BAL MFC NEMO model output converted to N...
#     institution:               Baltic MFC, PU Swedish Meteorological and Hydr...
#     copernicusmarine_version:  2.0.0

# %%
df_copernicus = copernicus_data.to_dataframe().reset_index()
# put column time in front
df_copernicus = df_copernicus[["time"] + [col for col in df_copernicus.columns if col != "time"]]

df_copernicus.dropna(axis=0, 
                     subset=["bottomT", "mlotst", "siconc", "sithick", "sla", "so", "sob", "thetao", "uo", "vo", "wo"], 
                     inplace=True,
                     how="all")

df_copernicus = process_dataframe(df_copernicus)

display(df_copernicus.info())

display(df_copernicus)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49915 entries, 47680 to 143039
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       49915 non-null  datetime64[ns]
#  1   depth      49915 non-null  float32
#  2   latitude   49915 non-null  float32
#  3   longitude  49915 non-null  float32
#  4   bottomT    49915 non-null  float32
#  5   mlotst     49915 non-null  float32
#  6   siconc     49915 non-null  float32
#  7   sithick    49915 non-null  float32
#  8   sla        49915 non-null  float32
#  9   so         49915 non-null  float32
#  10  sob        49915 non-null  float32
#  11  thetao     49915 non-null  float32
#  12  uo         49915 non-null  float32
#  13  vo         49915 non-null  float32
#  14  wo         49915 non-null  float32
# dtypes: datetime64[ns](1), float32(14)
# memory usage: 3.4 MB
# None
#                       time     depth   latitude  longitude   bottomT  \
# 47680  2025-01-01 00:00:00  0.501646  54.358276  10.152689  6.129929
# 47681  2025-01-01 01:00:00  0.501646  54.358276  10.152689  6.123942
# 47682  2025-01-01 02:00:00  0.501646  54.358276  10.152689  6.119880
# 47683  2025-01-01 03:00:00  0.501646  54.358276  10.152689  6.118432
# 47684  2025-01-01 04:00:00  0.501646  54.358276  10.152689  6.119393
# ...                    ...       ...        ...        ...       ...
# 143035 2025-01-31 20:00:00  0.501646  54.524940  10.347133  4.567245
# 143036 2025-01-31 21:00:00  0.501646  54.524940  10.347133  4.565339
# 143037 2025-01-31 22:00:00  0.501646  54.524940  10.347133  4.563229
# 143038 2025-01-31 23:00:00  0.501646  54.524940  10.347133  4.560693
# 143039 2025-02-01 00:00:00  0.501646  54.524940  10.347133  4.557865
#
#            mlotst  siconc  sithick       sla         so        sob    thetao  \
# 47680    5.590637     0.0      0.0 -0.783050  16.313734  16.313805  6.129667
# 47681    5.537246     0.0      0.0 -0.836441  16.280558  16.280558  6.123942
# 47682    5.485316     0.0      0.0 -0.888371  16.244640  16.244654  6.119825
# 47683    5.438865     0.0      0.0 -0.934821  16.206421  16.206537  6.118350
# 47684    5.390626     0.0      0.0 -0.983061  16.168251  16.168253  6.119394
# ...           ...     ...      ...       ...        ...        ...       ...
# 143035  10.031350     0.0      0.0 -0.111337  17.642529  19.848560  4.294259
# 143036  10.018709     0.0      0.0 -0.127637  17.571630  19.834522  4.283749
# 143037  10.015547     0.0      0.0 -0.131714  17.503935  19.819601  4.271446
# 143038  10.021186     0.0      0.0 -0.124443  17.430189  19.804668  4.257999
# 143039  10.035129     0.0      0.0 -0.106464  17.338272  19.790899  4.248519
#
#               uo        vo        wo
# 47680   0.007948  0.000000  0.000015
# 47681   0.004320  0.000000  0.000016
# 47682   0.004066  0.000000  0.000016
# 47683   0.003737  0.000000  0.000016
# 47684   0.003704  0.000000  0.000017
# ...          ...       ...       ...
# 143035  0.104553 -0.137242  0.000002
# 143036  0.103176 -0.145167  0.000002
# 143037  0.090108 -0.148308  0.000001
# 143038  0.060021 -0.145717  0.000001
# 143039  0.021965 -0.137783  0.000001
#
# [49915 rows x 15 columns]

# %%
db = Database(
    db_url=DB_URL,
    db_name=DB_NAME,
    collection_name=DB_COLLECTION
    )
    

db_data_all = db.get_all_data(key="time")
db.close_connection()

if db_data_all:
    df_db = pd.DataFrame(db_data_all).drop(columns=['_id']).loc[:, ['time', 'latitude', 'longitude']]


    df_db = process_dataframe(df_db)

    display(df_copernicus.shape)

    # Filtere Zeilen, die in df_db existieren
    db_tuples = set(zip(df_db["time"], df_db["latitude"], df_db["longitude"]))
    df_copernicus = df_copernicus[~df_copernicus.apply(lambda row: (row["time"], row["latitude"], row["longitude"]) in db_tuples, axis=1)]
    display(df_copernicus.shape)

# %%
# Helper Function
def upload_article_if_new(db_data, not_db_data):
    # Check if the article is already in the database
    for doc in db_data:
        if (doc.get('time') == not_db_data.get('time')) and (doc.get('latitude') == not_db_data.get('latitude')) and (doc.get('longitude') == not_db_data.get('longitude')):
            #print('Data already in the database, skipping upload...\n')
            return False
        
    return True

# %%
# cols = [
#     "time", "temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", 
#     "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth",
#     "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", 
#     "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", 
#     "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", 
#     "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", 
#     "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", 
#     "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", 
#     "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", 
#     "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", 
#     "soil_moisture_27_to_81cm"]


for idx, (time, latitude, longitude) in enumerate(tqdm(zip(df_copernicus['time'], df_copernicus['latitude'], df_copernicus['longitude']), desc='Processing data', total=len(df_copernicus))):
    

    # bring time to isoformat
    time = time.isoformat().split('T')[0]
    
    open_meteo_weather = OpenMeteoWeather(
    latitude=[latitude],
    longitude=[longitude],
    start_date=time,
    end_date=time
    ) 

    df_openweather = open_meteo_weather.get_weather_dataframe().rename(columns={"date": "time"})
    df_openweather['time'] = df_openweather['time'].dt.tz_localize(None) # convert datetime64[ns, UTC] to datetime64[ns]
    df_openweather['latitude'] = latitude
    df_openweather['longitude'] = longitude
    
    df_merged = pd.merge(df_copernicus, df_openweather, on=['time', 'latitude', 'longitude'], how='inner')
    df_merged = process_dataframe(df_merged)
    
    # upload to database
    df_json = df_merged.to_json(orient='records')
    df_json = json.loads(df_json)
    for item in df_json:
        item["time"] = pd.to_datetime(item["time"], unit='ms')


        db = Database(
            db_url=DB_URL,
            db_name=DB_NAME,
            collection_name=DB_COLLECTION
            )

        db_data_all = db.get_all_data(key="time")
        if upload_article_if_new(db_data_all, item) == False:
            continue

        db.upload_one(item)
        db.close_connection()
# Out:
# Processing data:   0%|          | 0/49915 [00:00<?, ?it/s]
# Processing data:   1%|          | 384/49915 [03:27<7:26:53,  1.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 49
#      40 item["time"] = pd.to_datetime(item["time"], unit='ms')
#      43 db = Database(
#      44     db_url=DB_URL,
#      45     db_name=DB_NAME,
#      46     collection_name=DB_COLLECTION
#      47     )
# ---> 49 db_data_all = db.get_all_data(key="time")
#      50 if upload_article_if_new(db_data_all, item) == False:
#      51     continue
#
# File ~/Documents/GEOMAR-DeepLearning/app/backend/utils/Database.py:49, in Database.get_all_data(self, key)
#      47 def get_all_data(self, key):
# ---> 49     data = list(self.collection.find().sort(key, -1))
#      50     return data
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1228, in Cursor._refresh(self)
#    1213     # Exhaust cursors don't send getMore messages.
#    1214     g = self._getmore_class(
#    1215         self._dbname,
#    1216         self._collname,
#    (...)
#    1226         self._comment,
#    1227     )
# -> 1228     self._send_message(g)
#    1230 return len(self._data)
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)
#    1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1745, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1738 def _cmd(
#    1739     _session: Optional[ClientSession],
#    1740     server: Server,
#    1741     conn: Connection,
#    1742     read_preference: _ServerMode,
#    1743 ) -> Response:
#    1744     operation.reset()  # Reset op in case of retry.
# -> 1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    1748         read_preference,
#    1749         self._event_listeners,
#    1750         unpack_res,
#    1751         self,
#    1752     )
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/pool.py:592, in Connection.receive_message(self, request_id)
#     590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
# --> 592     self._raise_connection_failure(error)
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/pool.py:590, in Connection.receive_message(self, request_id)
#     585 """Receive a raw BSON message or raise ConnectionFailure.
#     586
#     587 If any exception is raised, the socket is closed.
#     588 """
#     589 try:
# --> 590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
#     592     self._raise_connection_failure(error)
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/network.py:320, in receive_message(conn, request_id, max_message_size)
#     318         deadline = None
#     319 # Ignore the response's request id.
# --> 320 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     321 # No request_id for exhaust cursor "getMore".
#     322 if request_id is not None:
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/network.py:390, in _receive_data_on_socket(conn, length, deadline)
#     388 while bytes_read < length:
#     389     try:
# --> 390         wait_for_read(conn, deadline)
#     391         # CSOT: Update timeout. When the timeout has expired perform one
#     392         # final non-blocking recv. This helps avoid spurious timeouts when
#     393         # the response is actually already buffered on the client.
#     394         if _csot.get_timeout() and deadline is not None:
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/synchronous/network.py:375, in wait_for_read(conn, deadline)
#     373     else:
#     374         timeout = _POLL_TIMEOUT
# --> 375     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376 if conn.cancel_context.cancelled:
#     377     raise _OperationCancelled("operation cancelled")
#
# File ~/Documents/VirtualEnvironments/.main/lib/python3.11/site-packages/pymongo/socket_checker.py:66, in SocketChecker.select(self, sock, read, write, timeout)
#      62 try:
#      63     # poll() timeout is in milliseconds. select()
#      64     # timeout is in seconds.
#      65     timeout_ = None if timeout is None else timeout * 1000
# ---> 66     res = self._poller.poll(timeout_)
#      67     # poll returns a possibly-empty list containing
#      68     # (fd, event) 2-tuples for the descriptors that have
#      69     # events or errors to report. Return True if the list
#      70     # is not empty.
#      71     return bool(res)
#
# KeyboardInterrupt:
